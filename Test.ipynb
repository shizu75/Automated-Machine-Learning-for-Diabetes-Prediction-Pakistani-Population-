# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

d = pd.read_csv('/Content/Pakistani_Diabetes_Dataset.csv')
d.head()
# Out:
#     Age  Gender  Rgn     wt    BMI   wst  sys  dia  his   A1c  B.S.R  vision  \
# 0  60.0       1     0  76.0  29.90  41.0  130   90    0  8.90    278       0
# 1  57.0       1     1  64.0  24.30  39.0  120   80    1  8.50    165       0
# 2  58.0       0     0  73.0  25.20  34.0  140   90    0  5.65    130       1
# 3  27.0       0     1  60.0  22.01  30.0  110   70    0  5.00     95       0
# 4  56.0       1     0  70.0  25.80  43.0  125   90    0  8.30    139       1
#
#    Exr  dipsia  uria   Dur  neph  HDL  Outcome
# 0   30       1     0   5.0     0   60        1
# 1   20       1     1  20.0     0   42        1
# 2   20       0     0   0.0     0   54        0
# 3   15       0     0   0.0     0   57        0
# 4   40       1     0   5.0     1   53        1
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
from matplotlib import pyplot as plt
d['Outcome'].plot(kind='hist', bins=10, title='Outcome')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
d = d.drop_duplicates()

# %%
d.head()
# Out:
#     Age  Gender  Rgn     wt    BMI   wst  sys  dia  his   A1c  vision  Exr  \
# 0  60.0       1     0  76.0  29.90  41.0  130   90    0  8.90       0   30
# 1  57.0       1     1  64.0  24.30  39.0  120   80    1  8.50       0   20
# 2  58.0       0     0  73.0  25.20  34.0  140   90    0  5.65       1   20
# 3  27.0       0     1  60.0  22.01  30.0  110   70    0  5.00       0   15
# 4  56.0       1     0  70.0  25.80  43.0  125   90    0  8.30       1   40
#
#    dipsia  uria  neph  HDL  Outcome
# 0       1     0     0   60        1
# 1       1     1     0   42        1
# 2       0     0     0   54        0
# 3       0     0     0   57        0
# 4       1     0     1   53        1

# %%
d.shape
# Out:
# (909, 17)

# %%
X = d.drop('Outcome', axis=1)
Y = d['Outcome']

# %%
correlation_matrix = X.corr(numeric_only=True)

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()

# %%
X = X.drop(["B.S.R", "Dur"], axis = 1)

# %%
correlation_matrix = X.corr(numeric_only=True)

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()

# %%
d = d.drop(["B.S.R", "Dur"], axis = 1)

# %%
d.head()
# Out:
#     Age  Gender  Rgn     wt    BMI   wst  sys  dia  his   A1c  vision  Exr  \
# 0  60.0       1     0  76.0  29.90  41.0  130   90    0  8.90       0   30
# 1  57.0       1     1  64.0  24.30  39.0  120   80    1  8.50       0   20
# 2  58.0       0     0  73.0  25.20  34.0  140   90    0  5.65       1   20
# 3  27.0       0     1  60.0  22.01  30.0  110   70    0  5.00       0   15
# 4  56.0       1     0  70.0  25.80  43.0  125   90    0  8.30       1   40
#
#    dipsia  uria  neph  HDL  Outcome
# 0       1     0     0   60        1
# 1       1     1     0   42        1
# 2       0     0     0   54        0
# 3       0     0     0   57        0
# 4       1     0     1   53        1

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x_scaled = sc.fit_transform(X)

vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(x_scaled, i) for i in range(x_scaled.shape[1])]
vif_data["Tolerance"] = 1 / vif_data["VIF"]

print(vif_data)
# Out:
#    feature       VIF  Tolerance
# 0      Age  2.187181   0.457210
# 1   Gender  1.389039   0.719922
# 2     Rgn   1.012669   0.987489
# 3       wt  1.877811   0.532535
# 4      BMI  1.197051   0.835387
# 5      wst  2.162701   0.462385
# 6      sys  1.350001   0.740740
# 7      dia  1.297615   0.770645
# 8      his  1.039695   0.961820
# 9      A1c  2.152737   0.464525
# 10  vision  1.038695   0.962747
# 11     Exr  1.018120   0.982202
# 12  dipsia  1.523946   0.656191
# 13    uria  1.390799   0.719011
# 14    neph  1.214515   0.823374
# 15     HDL  1.245899   0.802634

# %%
from pycaret.classification import *
clf = setup(data = d, target = "Outcome")
# Out:
# <style type="text/css">
# #T_d147d_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d147d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d147d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d147d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d147d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d147d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d147d_row0_col1" class="data row0 col1" >5092</td>
#     </tr>
#     <tr>
#       <th id="T_d147d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d147d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d147d_row1_col1" class="data row1 col1" >Outcome</td>
#     </tr>
#     <tr>
#       <th id="T_d147d_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_0d85b th {
#   text-align: left;
# }
# ...

# %%
best_model = automl(optimize = 'Accuracy')

# %%
tuned_best_model = tune_model(best_model)
# Out:
# <style type="text/css">
# #T_6cf98_row10_col0, #T_6cf98_row10_col1, #T_6cf98_row10_col2, #T_6cf98_row10_col3, #T_6cf98_row10_col4, #T_6cf98_row10_col5, #T_6cf98_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_6cf98" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6cf98_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_6cf98_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_6cf98_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_6cf98_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_6cf98_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_6cf98_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_6cf98_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
best_model
# Out:
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device='cpu', early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=-1,
#               num_parallel_tree=None, objective='binary:logistic', ...)

# %%
tuned_best_model
# Out:
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device='cpu', early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=-1,
#               num_parallel_tree=None, objective='binary:logistic', ...)

# %%
tuned_best_model.get_params()
# Out:
# {'objective': 'binary:logistic',
#  'base_score': None,
#  'booster': 'gbtree',
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': None,
#  'device': 'cpu',
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'feature_types': None,
#  'gamma': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': None,
#  'max_bin': None,
#  'max_cat_threshold': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': None,
#  'max_depth': None,
#  'max_leaves': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'multi_strategy': None,
#  'n_estimators': None,
#  'n_jobs': -1,
#  'num_parallel_tree': None,
#  'random_state': 5092,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'subsample': None,
#  'tree_method': 'auto',
#  'validate_parameters': None,
# ...

# %%
plot_model(tuned_best_model, plot = 'confusion_matrix')

# %%
plot_model(tuned_best_model, plot = 'auc')

# %%
plot_model(tuned_best_model, plot = 'boundary')

# %%
evaluate_model(tuned_best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predictions = predict_model(tuned_best_model, data = d)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d8175" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8175_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d8175_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_d8175_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_d8175_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_d8175_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_d8175_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_d8175_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_d8175_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8175_level0_row0" class="row_heading level0 row0" >0</th>
# ...
